# %%
import pandas as pd

# %%
k = pd.read_excel("characters_cleaned.xlsx")
k
# Out:
#       mal_id               name  \
# 0     161471      Itsuki Nakano
# 1     161472        Nino Nakano
# 2     161470      Ichika Nakano
# 3     161469     Yotsuba Nakano
# 4     160603        Miku Nakano
# ...      ...                ...
# 2349  255515  Elynsia Teos Rave
# 2350  179681             Ai Mie
# 2351  216166      Yuika Hibuchi
# 2352  216165       Asuka Kawato
# 2353  216168      Narumi Someya
#
#                                                  series  genre  rarity  \
# 0                                  5-toubun no Hanayome  Anime       3
# 1                                  5-toubun no Hanayome  Anime       3
# 2                                  5-toubun no Hanayome  Anime       3
# 3                                  5-toubun no Hanayome  Anime       3
# 4                                  5-toubun no Hanayome  Anime       3
# ...                                                 ...    ...     ...
# 2349  Yarinaoshi Reijou wa Ryuutei Heika wo Kouryaku...  Anime       1
# ...

# %%
h = k[["mal_id","name","series"]]
h.to_csv("characters_input_for_llm.csv",index=False)

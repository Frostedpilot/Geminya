# %%
import pandas as pd

# %%
k = pd.read_excel("final/characters_cleaned.xlsx")
k
# Out:
#      source_type   source_id            name                series  \
# 0            mal      161471   Itsuki Nakano  5-toubun no Hanayome
# 1            mal      161472     Nino Nakano  5-toubun no Hanayome
# 2            mal      161470   Ichika Nakano  5-toubun no Hanayome
# 3            mal      161469  Yotsuba Nakano  5-toubun no Hanayome
# 4            mal      160603     Miku Nakano  5-toubun no Hanayome
# ...          ...         ...             ...                   ...
# 2452          ss  ss_cosette         Cosette           Stella Sora
# 2453          ss  ss_caramel         Caramel           Stella Sora
# 2454          ss     ss_noya            Noya           Stella Sora
# 2455          ss   ss_canace          Canace           Stella Sora
# 2456          ss      ss_ann             Ann           Stella Sora
#
#      series_source_id  genre  rarity  \
# 0               38101  Anime       3
# 1               38101  Anime       3
# 2               38101  Anime       3
# ...

# %%
h = k[["source_type","source_id","name","series"]]
h.to_csv("final/characters_input_for_llm.csv",index=False)
